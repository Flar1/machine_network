# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
iris = load_iris()
data = pd.DataFrame(data=iris.data, columns=iris.feature_names)
data['species'] = iris.target


data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
sns.pairplot(data, hue='species', palette='Set1')
plt.show()

# %% [markdown]
# Обучаем классификатор.

# %%
X = data[iris.feature_names]
y = data['species']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# Смотрим результат классификации.

# %%
predicted_data = X_test.copy()
predicted_data['Predicted Species'] = y_pred

predicted_data['Predicted Species'] = predicted_data['Predicted Species'].apply(lambda i: iris.target_names[i])
sns.pairplot(predicted_data, hue='Predicted Species', palette='Set2')
plt.show()
